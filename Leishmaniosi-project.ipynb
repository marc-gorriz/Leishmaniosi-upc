# %% [markdown]
# # Leishmaniosi project
# Marc Górriz · Elisa Sayrol · Verónica Vilaplana
#
# This is a Jupyter notebook to test the pre-trained models with new Leishmaniosi data.
#
# Available options:
#
#     1) list_directory: make a list of available images from specific path.
#     2) display_legend: show a legend of color-classes.
#     3) predict: make a prediction of an image.

# %%
from src.predictor import predict, list_directory, display_legend
# Out:
# Using TensorFlow backend.

# %%
img_path = 'img/'
weights_path = 'weights.hdf5'

list_directory(img_path)
# Out:
# image0.jpg

# %%
image_name = 'image0.jpg'

display_legend()
predict(img_path + image_name, weights_path, show_source=True, show_prediction=True)
# Out:
# 0 - Black   - Background
# 1 - Red     - Non-usable area
# 2 - Orange  - Non-parasite
# 3 - White   - Cytoplasm
# 4 - Magenta - Nucleus
# 5 - Blue    - Promastigote
# 6 - Green   - Adhered
# 7 - Cyan    - Amastigote
